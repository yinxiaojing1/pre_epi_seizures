# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %%
def dist_estimation(univariate_data,
                    dist_name):
    size = len(univariate_data)
    x = np.linspace(-4, 4, size)
    print x
    y = univariate_data.as_matrix()
    print y

    dist = getattr(scipy.stats, dist_name)
    param = dist.fit(y.T[0])
    pdf_fitted = dist.pdf(x,
                          *param[:-2],
                          loc=param[-2],
                          scale=param[-1])
   

    return x, pdf_fitted

# %%
mu, sigma = 0, 1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)
s = pd.DataFrame(s, columns=['Gaussian Noise'])

# %%
plt.figure()
s.plot(y='Gaussian Noise')
plt.show()

# %%
plt.plot()
sns.distplot(a=s, kde=False, bins=None, norm_hist=True)

# %%
x, pd = dist_estimation(s, 'norm')
len(pd)
plt.plot(x, pd)
# Out:
# [-4.         -3.99199199 -3.98398398 -3.97597598 -3.96796797 -3.95995996
#  -3.95195195 -3.94394394 -3.93593594 -3.92792793 -3.91991992 -3.91191191
#  -3.9039039  -3.8958959  -3.88788789 -3.87987988 -3.87187187 -3.86386386
#  -3.85585586 -3.84784785 -3.83983984 -3.83183183 -3.82382382 -3.81581582
#  -3.80780781 -3.7997998  -3.79179179 -3.78378378 -3.77577578 -3.76776777
#  -3.75975976 -3.75175175 -3.74374374 -3.73573574 -3.72772773 -3.71971972
#  -3.71171171 -3.7037037  -3.6956957  -3.68768769 -3.67967968 -3.67167167
#  -3.66366366 -3.65565566 -3.64764765 -3.63963964 -3.63163163 -3.62362362
#  -3.61561562 -3.60760761 -3.5995996  -3.59159159 -3.58358358 -3.57557558
#  -3.56756757 -3.55955956 -3.55155155 -3.54354354 -3.53553554 -3.52752753
#  -3.51951952 -3.51151151 -3.5035035  -3.4954955  -3.48748749 -3.47947948
#  -3.47147147 -3.46346346 -3.45545546 -3.44744745 -3.43943944 -3.43143143
#  -3.42342342 -3.41541542 -3.40740741 -3.3993994  -3.39139139 -3.38338338
# ...

# %%
plt.show()
