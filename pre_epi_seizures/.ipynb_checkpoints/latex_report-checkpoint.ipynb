# %%
from learning_pipelines import get_learning_results, get_hyper_param_results
import sklearn.svm as svm
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd

from classification.keras_neural_nets import *

import os
# Out:
# /home/franciscosargo/.virtualenvs/pre_epi_seizures/local/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import pylatex

# %%
import glob
import shutil
import os

# %%
from evaluation_tables import *

# %%
from classification.hp_opt.single_param import *

# %%
from learning_pipelines import load_eda

# %%
def create_tables_patient_specific(table):
        # Overal Patient Classification
        per_patient = table[['precision',
                             'recall',
                             'f1-score',
                             'patient_nr',
                             'Best Parameters',
                             'Labels']].groupby(['patient_nr', 'Labels']).describe()

        per_patient.loc[:, (['precision', 'recall', 'f1-score'], ['mean', 'std'])]

        # Overal Patient Classification
        per_patient = table[['precision',
                             'recall',
                             'f1-score',
                             'patient_nr',
                             'Best Parameters',
                             'Labels']].groupby(['Best Parameters','patient_nr', 'Labels']).describe()

        per_patient.loc[:, (['precision', 'recall', 'f1-score'], ['mean', 'std'])]
        
        print table

# %%
# Set the storage parameters 
disk = '/mnt/Seagate/pre_epi_seizures/'

# %%
# Set the latex report folder
latex_dir = 'latex/'

# %%
patient_lists = [[3], [4], [5], [8]]

# %%
# Allocate the feature set
feature_set = [('pca_beat_amp_computation', 0), ('hrv_time_features', 0)]

# %%
model_set = [
             (Pipeline([('KNN', KNeighborsClassifier())]), [{'KNN__n_neighbors': [i for i in xrange(1, 15, 2)]}]),
             (Pipeline([('GaussNB', GaussianNB())]), [{'GaussNB__priors': [None]}]),
             (Pipeline([('SVC', svm.SVC())]), [{'SVC__C': [2**i for i in xrange(-5, 11)], 
                                                'SVC__gamma':[2**i for i in xrange(-15, 1)]}])]

# %%
scaler_set = [StandardScaler()]

# %%
# Labeling structure
label_struct = {
                'inter_ictal':{
                    'label': 'Inter-Ictal Data Points',
                    'color': 'blue',
                    'intervals_samples': [(1000 * 0 * 60, 1000 * 20 * 60 )]
                             },
                'pre_ictal':{
                    'label': 'Pre-Ictal data points',
                    'color': 'yellow',
                    'intervals_samples': [(1000 * 20 * 60, 1000 * 49 * 60 )]
                             },
                'ictal':{
                    'label': 'Ictal data points',
                    'color': 'red',
                    'intervals_samples': [(1000 * 50 * 60, 1000 * 55 * 60 )]
                         },
                        }
baseline_label_struct = {
                 'baseline':{
                    'label': 'Baseline Data Points',
                    'color': 'green',
                    'intervals_samples': [(0, 1000 * 30 * 60 )]
                            },
                        }

plot_eda = False
learn_flag = False
compute_all_new = False

# %%
# Open latex document
eda_folder = 'EDanalysis_new/'
results_doc = pylatex.Document(default_filepath='/home/franciscosargo/results')
#results_doc = pylatex.Document(default_filepath=disk + eda_folder + 'results')

# %%
results_doc
# Out:
# Document('/home/franciscosargo/results', [Command(u'normalsize', Arguments(), Options())])

# %%
# Patient Specific results

for feature_slot, hyper_param in feature_set:
    
    print feature_slot
    print hyper_param
    
    with results_doc.create(pylatex.Section('The fancy stuff')):
    
        # Entry text, needs to be mended and corrected
        results_doc.append('The following results concern the feature set: ' + feature_slot)

        for patient_list in patient_lists:

            # Loop for scaler
            #for scaler in scaler_set:

            # Do some text
            #print 'Patient Number is' + str(patient_list)
            #print 'The Scaler is' + str(scaler)

            #print 'Here is a visualization of the normalized data'

            #print patient_list

            # EDA plots
            for scaler in scaler_set:

                # Loop for model
                for model in model_set:

                        # Unpack the variables of analysis
                        scaler = model[0]
                        pipe = model[1]
                        param_grid = model[2]


                        print 'The Hyper-Parameter Grid for optimization is:' + str(param_grid)

                        # Get table from original analysis
                        table = get_learning_results(label_struct, baseline_label_struct,
                                                      pipe, scaler, param_grid,
                                                      patient_list,
                                                      feature_slot,
                                                      hyper_param,
                                                      plot_eda,
                                                      learn_flag,
                                                      compute_all_new)

                        # Compute the statistics from the overall labels
                        per_label = evaluate_overall_labels(table)

                        # Compute the statistics for seizure type
                        per_type_of_seizure = evaluate_per_types_of_seizure(table)

                        # Get model name
                        model_name = pipe.steps[0][0]

                        # Get Hyper-parameterization results
                        cv_results=get_hyper_param_results(label_struct, baseline_label_struct,
                                                  pipe, scaler, param_grid,
                                                  patient_list,
                                                  feature_slot,
                                                  hyper_param,
                                                  plot_eda,
                                                  learn_flag,
                                                  compute_all_new)

                        param_name = param_grid[0].keys()[0]
                        single_param_var = param_grid[0][param_name]

                        single_mean_std_param_plot('fgjasljgf', 
                                                   cv_results, 
                                                   param_name, 
                                                   single_param_var,
                                                   feature_slot)

                        # Plot and save EDA



                        # Plot hyper-parameters function

                        single_mean_std_param_plot('fgjasljgf', 
                                       cv_results, 
                                       param_name, 
                                       single_param_var,
                                       feature_slot)

                        # 


                        # Get param

                        print per_label
                        print per_type_of_seizure
# Out:
# pca_beat_amp_computation
# 0
# ('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['ECG-'])('feature_slot', 'pca_beat_amp_computation')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [3])('hyper_param', 0)('group_id', 'seizure_nr')
#
# This is a list of the parameters
# ["('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['ECG-'])('feature_slot', 'pca_beat_amp_computation')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [3])('hyper_param', 0)('group_id', 'seizure_nr')", "('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['ECG-'])('feature_slot', 'pca_beat_amp_computation')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [4])('hyper_param', 0)('group_id', 'seizure_nr')", "('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['ECG-'])('feature_slot', 'pca_beat_amp_computation')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [5])('hyper_param', 0)('group_id', 'seizure_nr')", "('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['ECG-'])('feature_slot', 'pca_beat_amp_computation')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [8])('hyper_param', 0)('group_id', 'seizure_nr')"]
#
# This is the new one
# ('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['ECG-'])('feature_slot', 'pca_beat_amp_computation')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [3])('hyper_param', 0)('group_id', 'seizure_nr')
#
# id params in disk
#                                               params  \
# 0  ('scaler', StandardScaler(copy=True, with_mean...
#
#                                      id
# 0  5d9f23b0-4640-11e8-894a-b06ebfc25cc2
#
# Check if they are the same
#
#    params     id
# 0    True  False
#
# final id -- check disk
# 5d9f23b0-4640-11e8-894a-b06ebfc25cc2
#
# Check for this path on disk .. should be there
# 5d9f23b0-4640-11e8-894a-b06ebfc25cc2
# ["/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__PAIR.png", "/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__box.png", "/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__andrews.png", "/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__HIST.png", "/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__PAIR.png", "/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__box.png", "/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__andrews.png", "/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__HIST.png", "/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__PAIR.png", "/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__box.png", "/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__andrews.png", '/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/eig_value_5.png', '/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/eig_value_4.png', '/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/eig_value_3.png', '/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/eig_value_2.png', '/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/eig_value_1.png', "/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__HIST.png"]
# Latexmk: This is Latexmk, John Collins, 1 January 2015, version: 4.41.
# Rule 'pdflatex': File changes, etc:
#    Changed files, or newly in use since previous run(s):
#       'full.aux'
# ------------
# Run number 1 of rule 'pdflatex'
# ------------
# ------------
# Running 'pdflatex  --interaction=nonstopmode -recorder  "full.tex"'
# ------------
# Latexmk: applying rule 'pdflatex'...
# This is pdfTeX, Version 3.14159265-2.6-1.40.16 (TeX Live 2015/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./full.tex
# LaTeX2e <2016/02/01>
# Babel <3.9q> and hyphenation patterns for 81 language(s) loaded.
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2014/09/29 v1.4h Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty
# (/usr/share/texlive/texmf-dist/tex/latex/base/t1enc.def))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty
# (/usr/share/texlive/texmf-dist/tex/latex/base/utf8.def
# (/usr/share/texlive/texmf-dist/tex/latex/base/t1enc.dfu)
# (/usr/share/texlive/texmf-dist/tex/latex/base/ot1enc.dfu)
# (/usr/share/texlive/texmf-dist/tex/latex/base/omsenc.dfu)))
# (/usr/share/texmf/tex/latex/lm/lmodern.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty
# (/usr/share/texlive/texmf-dist/tex/latex/base/ts1enc.def
# (/usr/share/texlive/texmf-dist/tex/latex/base/ts1enc.dfu)))
# (/usr/share/texlive/texmf-dist/tex/latex/lastpage/lastpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/pdftex-def/pdftex.def
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/infwarerr.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ltxcmds.sty)))) (./full.aux
# ) (/usr/share/texlive/texmf-dist/tex/latex/base/ts1cmr.fd)
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd)
# (/usr/share/texlive/texmf-dist/tex/context/base/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# ) (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/pdftexcmds.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ifluatex.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ifpdf.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/epstopdf-base.sty
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/grfext.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/kvdefinekeys.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/kvoptions.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/kvsetkeys.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/etexcmds.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/epstopdf-sys.cfg))
# Overfull \hbox (18.05518pt too wide) in paragraph at lines 12--14
# []\T1/lmr/m/n/10 The fol-low-ing re-sults con-cern the fea-ture set: pca_beat_a
# mp_computationAfter
#
# Overfull \hbox (30.6939pt too wide) in paragraph at lines 12--14
# \T1/lmr/m/n/10 fea-ture ex-trac-tion and ap-pro-pri-ate nor-mal-iza-tion, us-in
# g: pca_beat_amp_computation
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.18 ...c2/('3', '2', 'F-A-M', 'Fl,Tl')__PAIR.png}
#                                                   %
# (/usr/share/texmf/tex/latex/lm/ot1lmr.fd)
# (/usr/share/texmf/tex/latex/lm/omllmm.fd)
# (/usr/share/texmf/tex/latex/lm/omslmsy.fd)
# (/usr/share/texmf/tex/latex/lm/omxlmex.fd)
# ! Missing { inserted.
# <to be read again>
#                    _
# l.18 ...c2/('3', '2', 'F-A-M', 'Fl,Tl')__PAIR.png}
#                                                   %
#
# LaTeX Warning: File `/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640
# -11e8-894a-b06ebfc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__PAIR.png' not found on in
# put line 18.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/('3', '2', 'F-A-M', 'Fl,Tl')__PAIR.png, id=1, 1047.915pt x 903.375pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__PAIR.png>
# ! Missing } inserted.
# <inserted text>
#                 }
# l.18 ...c2/('3', '2', 'F-A-M', 'Fl,Tl')__PAIR.png}
#                                                   %
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.18 ...c2/('3', '2', 'F-A-M', 'Fl,Tl')__PAIR.png}
#                                                   %
#
# Overfull \hbox (0.529pt too wide) in paragraph at lines 18--19
#  \T1/lmr/m/n/10 'Fl,Tl')$[]$
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.27 ...cc2/('3', '2', 'F-A-M', 'Fl,Tl')__box.png}
#                                                   %
# ! Missing { inserted.
# <to be read again>
#                    _
# l.27 ...cc2/('3', '2', 'F-A-M', 'Fl,Tl')__box.png}
#                                                   %
#
# LaTeX Warning: File `/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640
# -11e8-894a-b06ebfc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__box.png' not found on inp
# ut line 27.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/('3', '2', 'F-A-M', 'Fl,Tl')__box.png, id=3, 1445.4pt x 1445.4pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__box.png>
# ! Missing } inserted.
# <inserted text>
#                 }
# l.27 ...cc2/('3', '2', 'F-A-M', 'Fl,Tl')__box.png}
#                                                   %
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.27 ...cc2/('3', '2', 'F-A-M', 'Fl,Tl')__box.png}
#                                                   %
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.36 ...('3', '2', 'F-A-M', 'Fl,Tl')__andrews.png}
#                                                   %
# ! Missing { inserted.
# <to be read again>
#                    _
# l.36 ...('3', '2', 'F-A-M', 'Fl,Tl')__andrews.png}
#                                                   %
#
# LaTeX Warning: File `/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640
# -11e8-894a-b06ebfc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__andrews.png' not found on
#  input line 36.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/('3', '2', 'F-A-M', 'Fl,Tl')__andrews.png, id=4, 1445.4pt x 1445.4pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__andrews.png>
# ! Missing } inserted.
# <inserted text>
#                 }
# l.36 ...('3', '2', 'F-A-M', 'Fl,Tl')__andrews.png}
#                                                   %
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.36 ...('3', '2', 'F-A-M', 'Fl,Tl')__andrews.png}
#                                                   %
#
# Overfull \hbox (9.57039pt too wide) in paragraph at lines 36--37
#  \T1/lmr/m/n/10 'Fl,Tl')$[]$
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.45 ...c2/('3', '2', 'F-A-M', 'Fl,Tl')__HIST.png}
#                                                   %
# ! Missing { inserted.
# <to be read again>
#                    _
# l.45 ...c2/('3', '2', 'F-A-M', 'Fl,Tl')__HIST.png}
#                                                   %
#
# LaTeX Warning: File `/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640
# -11e8-894a-b06ebfc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__HIST.png' not found on in
# put line 45.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/('3', '2', 'F-A-M', 'Fl,Tl')__HIST.png, id=5, 1445.4pt x 1445.4pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__HIST.png>
# ! Missing } inserted.
# <inserted text>
#                 }
# l.45 ...c2/('3', '2', 'F-A-M', 'Fl,Tl')__HIST.png}
#                                                   %
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.45 ...c2/('3', '2', 'F-A-M', 'Fl,Tl')__HIST.png}
#                                                   %
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.54 .../('3', '1', 'F-NA-M', 'FTl,Tl')__PAIR.png}
#                                                   %
# ! Missing { inserted.
# <to be read again>
#                    _
# l.54 .../('3', '1', 'F-NA-M', 'FTl,Tl')__PAIR.png}
#                                                   %
#
# LaTeX Warning: File `/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640
# -11e8-894a-b06ebfc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__PAIR.png' not found on
# input line 54.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__PAIR.png, id=6, 1047.915pt x 903.375pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__PAIR.png>
# ! Missing } inserted.
# <inserted text>
#                 }
# l.54 .../('3', '1', 'F-NA-M', 'FTl,Tl')__PAIR.png}
#                                                   %
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.54 .../('3', '1', 'F-NA-M', 'FTl,Tl')__PAIR.png}
#                                                   %
#
# Overfull \hbox (7.751pt too wide) in paragraph at lines 54--55
#  \T1/lmr/m/n/10 'FTl,Tl')$[]$
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.63 ...2/('3', '1', 'F-NA-M', 'FTl,Tl')__box.png}
#                                                   %
# ! Missing { inserted.
# <to be read again>
#                    _
# l.63 ...2/('3', '1', 'F-NA-M', 'FTl,Tl')__box.png}
#                                                   %
#
# LaTeX Warning: File `/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640
# -11e8-894a-b06ebfc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__box.png' not found on i
# nput line 63.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__box.png, id=7, 1445.4pt x 1445.4pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__box.png>
# ! Missing } inserted.
# <inserted text>
#                 }
# l.63 ...2/('3', '1', 'F-NA-M', 'FTl,Tl')__box.png}
#                                                   %
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.63 ...2/('3', '1', 'F-NA-M', 'FTl,Tl')__box.png}
#                                                   %
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.72 ...3', '1', 'F-NA-M', 'FTl,Tl')__andrews.png}
#                                                   %
# ! Missing { inserted.
# <to be read again>
#                    _
# l.72 ...3', '1', 'F-NA-M', 'FTl,Tl')__andrews.png}
#                                                   %
#
# LaTeX Warning: File `/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640
# -11e8-894a-b06ebfc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__andrews.png' not found
# on input line 72.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__andrews.png, id=8, 1445.4pt x 1445.4pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__andrews.png>
# ! Missing } inserted.
# <inserted text>
#                 }
# l.72 ...3', '1', 'F-NA-M', 'FTl,Tl')__andrews.png}
#                                                   %
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.72 ...3', '1', 'F-NA-M', 'FTl,Tl')__andrews.png}
#                                                   %
#
# Overfull \hbox (16.79239pt too wide) in paragraph at lines 72--73
#  \T1/lmr/m/n/10 'FTl,Tl')$[]$
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.81 .../('3', '1', 'F-NA-M', 'FTl,Tl')__HIST.png}
#                                                   %
# ! Missing { inserted.
# <to be read again>
#                    _
# l.81 .../('3', '1', 'F-NA-M', 'FTl,Tl')__HIST.png}
#                                                   %
#
# LaTeX Warning: File `/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640
# -11e8-894a-b06ebfc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__HIST.png' not found on
# input line 81.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__HIST.png, id=9, 1445.4pt x 1445.4pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__HIST.png>
# ! Missing } inserted.
# <inserted text>
#                 }
# l.81 .../('3', '1', 'F-NA-M', 'FTl,Tl')__HIST.png}
#                                                   %
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.81 .../('3', '1', 'F-NA-M', 'FTl,Tl')__HIST.png}
#                                                   %
#
# Overfull \hbox (7.01799pt too wide) in paragraph at lines 81--82
#  \T1/lmr/m/n/10 'FTl,Tl')$[]$
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.90 ... '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__PAIR.png}
#                                                   %
# ! Missing { inserted.
# <to be read again>
#                    _
# l.90 ... '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__PAIR.png}
#                                                   %
#
# LaTeX Warning: File `/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640
# -11e8-894a-b06ebfc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__PAIR.png' not fou
# nd on input line 90.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__PAIR.png, id=10, 1047.915pt x 903.375
# pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__PAIR.png>
# ! Missing } inserted.
# <inserted text>
#                 }
# l.90 ... '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__PAIR.png}
#                                                   %
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.90 ... '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__PAIR.png}
#                                                   %
#
# Overfull \hbox (5.5844pt too wide) in paragraph at lines 90--91
#  \T1/lmr/m/n/10 FTr,Tr')$[]$
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.99 ..., '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__box.png}
#                                                   %
# ! Missing { inserted.
# <to be read again>
#                    _
# l.99 ..., '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__box.png}
#                                                   %
#
# LaTeX Warning: File `/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640
# -11e8-894a-b06ebfc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__box.png' not foun
# d on input line 99.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__box.png, id=11, 1445.4pt x 1445.4pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__box.png>
# ! Missing } inserted.
# <inserted text>
#                 }
# l.99 ..., '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__box.png}
#                                                   %
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.99 ..., '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__box.png}
#                                                   %
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.108 ..., 'G-A-M', 'FTl,Tl-FTr,Tr')__andrews.png}
#                                                   %
# ! Missing { inserted.
# <to be read again>
#                    _
# l.108 ..., 'G-A-M', 'FTl,Tl-FTr,Tr')__andrews.png}
#                                                   %
#
# LaTeX Warning: File `/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640
# -11e8-894a-b06ebfc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__andrews.png' not
# found on input line 108.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__andrews.png, id=12, 1445.4pt x 1445.4
# pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__andrews.png>
# ! Missing } inserted.
# <inserted text>
#                 }
# l.108 ..., 'G-A-M', 'FTl,Tl-FTr,Tr')__andrews.png}
#                                                   %
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.108 ..., 'G-A-M', 'FTl,Tl-FTr,Tr')__andrews.png}
#                                                   %
#
# Overfull \hbox (14.62578pt too wide) in paragraph at lines 108--109
#  \T1/lmr/m/n/10 FTr,Tr')$[]$
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/eig_value_5.png, id=13, 433.62pt x 289.08pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/eig_value_5.png>
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/eig_value_4.png, id=14, 433.62pt x 289.08pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/eig_value_4.png>
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/eig_value_3.png, id=15, 433.62pt x 289.08pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/eig_value_3.png>
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/eig_value_2.png, id=16, 433.62pt x 289.08pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/eig_value_2.png>
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/eig_value_1.png, id=17, 433.62pt x 289.08pt>
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/eig_value_1.png>
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.162 ...'0', 'G-A-M', 'FTl,Tl-FTr,Tr')__HIST.png}
#                                                   %
# ! Missing { inserted.
# <to be read again>
#                    _
# l.162 ...'0', 'G-A-M', 'FTl,Tl-FTr,Tr')__HIST.png}
#                                                   %
#
# LaTeX Warning: File `/mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640
# -11e8-894a-b06ebfc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__HIST.png' not fou
# nd on input line 162.
#
#
# </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25
# cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__HIST.png, id=18, 1445.4pt x 1445.4pt>
#
# <use /mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06eb
# fc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__HIST.png>
# ! Missing } inserted.
# <inserted text>
#                 }
# l.162 ...'0', 'G-A-M', 'FTl,Tl-FTr,Tr')__HIST.png}
#                                                   %
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.162 ...'0', 'G-A-M', 'FTl,Tl-FTr,Tr')__HIST.png}
#                                                   %
#
# Overfull \hbox (4.85138pt too wide) in paragraph at lines 162--163
#  \T1/lmr/m/n/10 FTr,Tr')$[]$
#
# LaTeX Warning: `!h' float specifier changed to `!ht'.
#
#
# AED: lastpage setting LastPage
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map} </mnt/Seagate/pre_epi_sei
# zures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '2', 'F-A-M', '
# Fl,Tl')__PAIR.png>] [2 </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4
# 640-11e8-894a-b06ebfc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__box.png>] [3 </mnt/Sea
# gate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3',
#  '2', 'F-A-M', 'Fl,Tl')__andrews.png>] [4 </mnt/Seagate/pre_epi_seizures/EDanal
# ysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '2', 'F-A-M', 'Fl,Tl')__HIS
# T.png>] [5 </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894
# a-b06ebfc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__PAIR.png>] [6 </mnt/Seagate/pre_
# epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '1', 'F-
# NA-M', 'FTl,Tl')__box.png>] [7 </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d
# 9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__andrews.png>
# ] [8 </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06e
# bfc25cc2/('3', '1', 'F-NA-M', 'FTl,Tl')__HIST.png>] [9 </mnt/Seagate/pre_epi_se
# izures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '0', 'G-A-M',
# 'FTl,Tl-FTr,Tr')__PAIR.png>] [10 </mnt/Seagate/pre_epi_seizures/EDanalysis_new/
# 5d9f23b0-4640-11e8-894a-b06ebfc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__box.
# png>] [11 </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a
# -b06ebfc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__andrews.png> </mnt/Seagate/
# pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/eig_value_
# 5.png>] [12 </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-89
# 4a-b06ebfc25cc2/eig_value_4.png> </mnt/Seagate/pre_epi_seizures/EDanalysis_new/
# 5d9f23b0-4640-11e8-894a-b06ebfc25cc2/eig_value_3.png>] [13 </mnt/Seagate/pre_ep
# i_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc25cc2/eig_value_2.png>
#  </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23b0-4640-11e8-894a-b06ebfc2
# 5cc2/eig_value_1.png>] [14 </mnt/Seagate/pre_epi_seizures/EDanalysis_new/5d9f23
# b0-4640-11e8-894a-b06ebfc25cc2/('3', '0', 'G-A-M', 'FTl,Tl-FTr,Tr')__HIST.png>]
#  (./full.aux) )
# (see the transcript file for additional information){/usr/share/texmf/fonts/enc
# /dvips/lm/lm-mathit.enc}{/usr/share/texmf/fonts/enc/dvips/lm/lm-ec.enc}</usr/sh
# are/texmf/fonts/type1/public/lm/lmmi5.pfb></usr/share/texmf/fonts/type1/public/
# lm/lmmi7.pfb></usr/share/texmf/fonts/type1/public/lm/lmr10.pfb>
# Output written on full.pdf (14 pages, 1860772 bytes).
# Transcript written on full.log.
# Latexmk: Log file says output to 'full.pdf'
# Collected error summary (may duplicate other messages):
#   pdflatex: Command for 'pdflatex' gave return code 256
# Latexmk: Use the -f option to force complete processing,
#  unless error was exceeding maximum runs of latex/pdflatex.
# Latexmk: Errors, so I did not complete making targets
# --------------------------------------------------------------------------
# CalledProcessError                       Traceback (most recent call last)
# <ipython-input-17-0b56dd5743bd> in <module>()
#      46
#      47
# ---> 48                 results_doc.generate_pdf('/home/franciscosargo/full', clean_tex=False)
#      49                 stop
#      50
#
# /home/franciscosargo/.virtualenvs/pre_epi_seizures/local/lib/python2.7/site-packages/pylatex/document.pyc in generate_pdf(self, filepath, **_3to2kwargs)
#     267             try:
#     268                 output = subprocess.check_output(command,
# --> 269                                                  stderr=subprocess.STDOUT)
#     270             except (OSError, IOError), e:
#     271                 # Use FileNotFoundError when python 2 is dropped
#
# /usr/lib/python2.7/subprocess.pyc in check_output(*popenargs, **kwargs)
#     572         if cmd is None:
#     573             cmd = popenargs[0]
# --> 574         raise CalledProcessError(retcode, cmd, output=output)
#     575     return output
#     576
#
# CalledProcessError: Command '[u'latexmk', u'--pdf', u'--interaction=nonstopmode', u'full.tex']' returned non-zero exit status 12
