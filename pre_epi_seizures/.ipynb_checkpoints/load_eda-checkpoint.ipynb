# %%
'''BE CAREFUL RUNNIG THIS SCRIPT CAN OVERWRIE THE WHOLE DATA ON DISK'''
# Out:
# 'BE CAREFUL RUNNIG THIS SCRIPT CAN OVERWRIE THE WHOLE DATA ON DISK'

# %%
'''BE CAREFUL CHANGING THE LABELS STRUCTURE, MAKE SURE TO CHANGE classification/cross_validation.parse_classification_report'''
# Out:
# 'BE CAREFUL CHANGING THE LABELS STRUCTURE, MAKE SURE TO CHANGE classification/cross_validation.parse_classification_report'

# %%
# Imports
# Modelation
import sklearn.svm as svm
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

from classification.keras_neural_nets import *

import os
# Out:
# /home/franciscosargo/.virtualenvs/pre_epi_seizures/local/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from learning_pipelines import supervised_pipeline, plot_eda, load_eda

# %%
# arguments
label_struct = {
                        'inter_ictal':{
                            'label': 'Inter-Ictal Data Points',
                            'color': 'blue',
                            'intervals_samples': [(1000 * 0 * 60, 1000 * 20 * 60 )]
                                     },
                        'pre_ictal':{
                            'label': 'Pre-Ictal data points',
                            'color': 'yellow',
                            'intervals_samples': [(1000 * 20 * 60, 1000 * 49 * 60 )]
                                     },
                        'ictal':{
                            'label': 'Ictal data points',
                            'color': 'red',
                            'intervals_samples': [(1000 * 50 * 60, 1000 * 55 * 60 )]
                                 },
                        }
baseline_label_struct = {
                         'baseline':{
                            'label': 'Baseline Data Points',
                            'color': 'green',
                            'intervals_samples': [(0, 1000 * 30 * 60 )]
                                    },
                        }



param_grid = [
              {'ANN__epochs': [10],
               'ANN__batch_size': [100],
               'ANN__hidden_layers_nr': [1],
               'ANN__hidden_nodes_per_layer': [i for i in xrange(3, 13)],
               'ANN__hidden_nodes_activation': ['relu']
              }
]
pipe = Pipeline( [('ANN', KerasClassifier(build_fn=dense_network,
                                        input_dim = 5,
                                          output_dim = 3,
                                          verbose=0))])

pipe = Pipeline([('SVC', svm.SVC())])
param_grid = [{'SVC__C': [2**i for i in xrange(-5, 11)], 
                'SVC__gamma':[2**i for i in xrange(-15, 1)]}]

pipe = Pipeline([('GaussNB', GaussianNB())])
param_grid = [
              {'GaussNB__priors': [None]},
]

pipe = Pipeline([('KNN', KNeighborsClassifier())])
param_grid = [{'KNN__n_neighbors': [i for i in xrange(1, 15, 2)]}]



feature_slot = 'hrv_computation'
hyper_param=0

scaler = StandardScaler()

learn_flag=True
compute_all_new=True
plot_eda_all_new=True

# %%
patient_lists = [[3]]


for patient_list in patient_lists:
    

    load_eda(label_struct, baseline_label_struct,
             scaler,
             patient_list,
             feature_slot,
             hyper_param
            )
# Out:
# [2018-04-24 12:56:42.489685]:get_signal:20:Loading [signal: 3_FA7774DK_Ecg_2017-04-20 07:38:44.000000_0][group: /3000_1200/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:4200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:42.498808]:get_signal:20:Loading [signal: 3_FA7774DR_Ecg_2017-04-20 16:09:45.000000_1][group: /3000_1200/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:4200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:42.508230]:get_signal:20:Loading [signal: 3_FA7774DT_Ecg_2017-04-20 20:10:11.000000_2][group: /3000_1200/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:4200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:42.518048]:get_signal:20:Loading [signal: 3_FA7774DK_Ecg_2017-04-20 07:38:44.000000_0][group: /3000_1200/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:4200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:42.527269]:get_signal:20:Loading [signal: 3_FA7774DR_Ecg_2017-04-20 16:09:45.000000_1][group: /3000_1200/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:4200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:42.536735]:get_signal:20:Loading [signal: 3_FA7774DT_Ecg_2017-04-20 20:10:11.000000_2][group: /3000_1200/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:4200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:42.548723]:get_signal:20:Loading [signal: window_3_FA7774DK_Ecg_2017-04-20 07:38:44.000000_0][group: /3000_1200/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:4200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:42.558705]:get_signal:20:Loading [signal: window_3_FA7774DR_Ecg_2017-04-20 16:09:45.000000_1][group: /3000_1200/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:4200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:42.568669]:get_signal:20:Loading [signal: window_3_FA7774DT_Ecg_2017-04-20 20:10:11.000000_2][group: /3000_1200/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:4200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# ('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['Ecg'])('feature_slot', 'hrv_computation')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [3])('hyper_param', 0)('group_id', 'seizure_nr')
#
# This is a list of the parameters
# ["('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['ECG-'])('feature_slot', 'pca_beat_amp_computation')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [3])('hyper_param', 0)('group_id', 'seizure_nr')", "('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['ECG-'])('feature_slot', 'pca_beat_amp_computation')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [4])('hyper_param', 0)('group_id', 'seizure_nr')", "('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['ECG-'])('feature_slot', 'pca_beat_amp_computation')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [5])('hyper_param', 0)('group_id', 'seizure_nr')", "('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['ECG-'])('feature_slot', 'pca_beat_amp_computation')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [8])('hyper_param', 0)('group_id', 'seizure_nr')", "('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['ECG-'])('feature_slot', 'hrv_time_features')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [3])('hyper_param', 0)('group_id', 'seizur ...
#
# This is the new one
# ('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))('lead_list', ['Ecg'])('feature_slot', 'hrv_computation')('interim_processing', [StandardScaler(copy=True, with_mean=True, with_std=True)])('assign_baseline', 'assign_equal_baseline_seizure')('label_struct', {'pre_ictal': {'color': 'yellow', 'intervals_samples': [(1200000, 2940000)], 'label': 'Pre-Ictal data points'}, 'inter_ictal': {'color': 'blue', 'intervals_samples': [(0, 1200000)], 'label': 'Inter-Ictal Data Points'}, 'ictal': {'color': 'red', 'intervals_samples': [(3000000, 3300000)], 'label': 'Ictal data points'}})('baseline_label_struct', {'baseline': {'color': 'green', 'intervals_samples': [(0, 1800000)], 'label': 'Baseline Data Points'}})('patient_list', [3])('hyper_param', 0)('group_id', 'seizure_nr')
#
# id params in disk
#                                               params  \
# 0  ('scaler', StandardScaler(copy=True, with_mean...
#
#                                      id
# 0  a0197924-46f5-11e8-894a-b06ebfc25cc2
#
# Check if they are the same
#
#    params     id
# 0    True  False
#
# final id -- check disk
# a0197924-46f5-11e8-894a-b06ebfc25cc2
#
# Check for this path on disk .. should be there
# a0197924-46f5-11e8-894a-b06ebfc25cc2
# /mnt/Seagate/pre_epi_seizures/EDanalysis_new/a0197924-46f5-11e8-894a-b06ebfc25cc2/
# you are at interim process!
# This is the feature name
# /3000_1200/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:4200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_
# trying to load seizure data
# closed
# closed
# closed
# data
# 3
# 0
# data
# 3
# 1
# data
# 3
# 2
# [2018-04-24 12:56:46.269551]:get_signal:20:Loading [signal: 3_FA7774DI_Ecg_2017-04-20 03:38:19.000000][group: /raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:46.285101]:get_signal:20:Loading [signal: 3_FA7774DJ_Ecg_2017-04-20 05:38:32.000000][group: /raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:46.300956]:get_signal:20:Loading [signal: 3_FA7774DI_Ecg_2017-04-20 03:38:19.000000][group: /raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:46.316510]:get_signal:20:Loading [signal: 3_FA7774DJ_Ecg_2017-04-20 05:38:32.000000][group: /raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:46.335289]:get_signal:20:Loading [signal: window_3_FA7774DI_Ecg_2017-04-20 03:38:19.000000][group: /raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# [2018-04-24 12:56:46.351960]:get_signal:20:Loading [signal: window_3_FA7774DJ_Ecg_2017-04-20 05:38:32.000000][group: /raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_]
# Here is the data
#               hrv  time_sample patient_nr seizure_nr                    label  \
# 0        1.081000         2100          3          0  Inter-Ictal Data Points
# 1        1.081007         2101          3          0  Inter-Ictal Data Points
# 2        1.081013         2102          3          0  Inter-Ictal Data Points
# 3        1.081020         2103          3          0  Inter-Ictal Data Points
# 4        1.081027         2104          3          0  Inter-Ictal Data Points
# 5        1.081034         2105          3          0  Inter-Ictal Data Points
# 6        1.081041         2106          3          0  Inter-Ictal Data Points
# 7        1.081048         2107          3          0  Inter-Ictal Data Points
# 8        1.081055         2108          3          0  Inter-Ictal Data Points
# 9        1.081061         2109          3          0  Inter-Ictal Data Points
# 10       1.081068         2110          3          0  Inter-Ictal Data Points
# 11       1.081075         2111          3          0  Inter-Ictal Data Points
# 12       1.081082         2112          3          0  Inter-Ictal Data Points
# 13       1.081089         2113          3          0  Inter-Ictal Data Points
# 14       1.081097         2114          3          0  Inter-Ictal Data Points
# 15       1.081104         2115          3          0  Inter-Ictal Data Points
# 16       1.081111         2116          3          0  Inter-Ictal Data Points
# 17       1.081118         2117          3          0  Inter-Ictal Data Points
# 18       1.081125         2118          3          0  Inter-Ictal Data Points
# 19       1.081132         2119          3          0  Inter-Ictal Data Points
# 20       1.081140         2120          3          0  Inter-Ictal Data Points
# 21       1.081147         2121          3          0  Inter-Ictal Data Points
# 22       1.081154         2122          3          0  Inter-Ictal Data Points
# 23       1.081161         2123          3          0  Inter-Ictal Data Points
# 24       1.081169         2124          3          0  Inter-Ictal Data Points
# 25       1.081176         2125          3          0  Inter-Ictal Data Points
# 26       1.081183         2126          3          0  Inter-Ictal Data Points
# 27       1.081191         2127          3          0  Inter-Ictal Data Points
# 28       1.081198         2128          3          0  Inter-Ictal Data Points
# 29       1.081206         2129          3          0  Inter-Ictal Data Points
# ...           ...          ...        ...        ...                      ...
# 4198511  0.790879      4199719          3          2                      NaN
# 4198512  0.790883      4199720          3          2                      NaN
# 4198513  0.790887      4199721          3          2                      NaN
# 4198514  0.790891      4199722          3          2                      NaN
# 4198515  0.790895      4199723          3          2                      NaN
# 4198516  0.790899      4199724          3          2                      NaN
# 4198517  0.790903      4199725          3          2                      NaN
# 4198518  0.790908      4199726          3          2                      NaN
# 4198519  0.790912      4199727          3          2                      NaN
# 4198520  0.790916      4199728          3          2                      NaN
# 4198521  0.790920      4199729          3          2                      NaN
# 4198522  0.790924      4199730          3          2                      NaN
# 4198523  0.790928      4199731          3          2                      NaN
# 4198524  0.790932      4199732          3          2                      NaN
# 4198525  0.790936      4199733          3          2                      NaN
# 4198526  0.790940      4199734          3          2                      NaN
# 4198527  0.790945      4199735          3          2                      NaN
# 4198528  0.790949      4199736          3          2                      NaN
# 4198529  0.790953      4199737          3          2                      NaN
# 4198530  0.790957      4199738          3          2                      NaN
# 4198531  0.790961      4199739          3          2                      NaN
# 4198532  0.790966      4199740          3          2                      NaN
# 4198533  0.790970      4199741          3          2                      NaN
# 4198534  0.790974      4199742          3          2                      NaN
# 4198535  0.790978      4199743          3          2                      NaN
# 4198536  0.790983      4199744          3          2                      NaN
# 4198537  0.790987      4199745          3          2                      NaN
# 4198538  0.790991      4199746          3          2                      NaN
# 4198539  0.790996      4199747          3          2                      NaN
# 4198540  0.791000      4199748          3          2                      NaN
#
#         color
# 0        blue
# 1        blue
# 2        blue
# 3        blue
# 4        blue
# 5        blue
# 6        blue
# 7        blue
# 8        blue
# 9        blue
# 10       blue
# 11       blue
# 12       blue
# 13       blue
# 14       blue
# 15       blue
# 16       blue
# 17       blue
# 18       blue
# 19       blue
# 20       blue
# 21       blue
# 22       blue
# 23       blue
# 24       blue
# 25       blue
# 26       blue
# 27       blue
# 28       blue
# 29       blue
# ...       ...
# 4198511     m
# 4198512     m
# 4198513     m
# 4198514     m
# 4198515     m
# 4198516     m
# 4198517     m
# 4198518     m
# 4198519     m
# 4198520     m
# 4198521     m
# 4198522     m
# 4198523     m
# 4198524     m
# 4198525     m
# 4198526     m
# 4198527     m
# 4198528     m
# 4198529     m
# 4198530     m
# 4198531     m
# 4198532     m
# 4198533     m
# 4198534     m
# 4198535     m
# 4198536     m
# 4198537     m
# 4198538     m
# 4198539     m
# 4198540     m
#
# [12594997 rows x 6 columns]
#
# ['/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_', '/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_/hrv_time_features_$beginwin_win:120__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_', '/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_/hrv_time_features_$beginwin_win:180__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_', '/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_raw_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_', '/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_raw_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_', '/raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_raw_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_']
#
# /raw_$beginwin_samplerate:1000_win:0.001_init:0_finish:7200_endwin$__$beginparams_param:None_endparam$_/baseline_removal_$beginwin_win:0.001__init:0__finish:4200__samplerate:1000_endwin$__$beginparam_filt:MedianFIR_endparam$_/rpeak_detection_$beginwin_win:rpeaks__samplerate:1000_endwin$__$beginparam_method:hamilton_endparam$_/hrv_computation_$beginwin_win:0.001__init:rpeaks[0]__finish:rpeaks[-1]__samplerate:1000_endwin$__$beginparam_method:hamilton__resampling:spline_endparam$_
# trying to load baseline data
# closed
# closed
# closed
# data
# 3
# 0
# data
# 3
# 0
# Here is the baseline data
#               hrv  time_sample patient_nr seizure_nr                 label  \
# 0        1.878000         2195          3          0  Baseline Data Points
# 1        1.875876         2196          3          0  Baseline Data Points
# 2        1.873756         2197          3          0  Baseline Data Points
# 3        1.871638         2198          3          0  Baseline Data Points
# 4        1.869522         2199          3          0  Baseline Data Points
# 5        1.867410         2200          3          0  Baseline Data Points
# 6        1.865300         2201          3          0  Baseline Data Points
# 7        1.863193         2202          3          0  Baseline Data Points
# 8        1.861089         2203          3          0  Baseline Data Points
# 9        1.858988         2204          3          0  Baseline Data Points
# 10       1.856889         2205          3          0  Baseline Data Points
# 11       1.854793         2206          3          0  Baseline Data Points
# 12       1.852700         2207          3          0  Baseline Data Points
# 13       1.850610         2208          3          0  Baseline Data Points
# 14       1.848522         2209          3          0  Baseline Data Points
# 15       1.846437         2210          3          0  Baseline Data Points
# 16       1.844355         2211          3          0  Baseline Data Points
# 17       1.842276         2212          3          0  Baseline Data Points
# 18       1.840199         2213          3          0  Baseline Data Points
# 19       1.838125         2214          3          0  Baseline Data Points
# 20       1.836054         2215          3          0  Baseline Data Points
# 21       1.833986         2216          3          0  Baseline Data Points
# 22       1.831920         2217          3          0  Baseline Data Points
# 23       1.829858         2218          3          0  Baseline Data Points
# 24       1.827798         2219          3          0  Baseline Data Points
# 25       1.825740         2220          3          0  Baseline Data Points
# 26       1.823686         2221          3          0  Baseline Data Points
# 27       1.821634         2222          3          0  Baseline Data Points
# 28       1.819585         2223          3          0  Baseline Data Points
# 29       1.817538         2224          3          0  Baseline Data Points
# ...           ...          ...        ...        ...                   ...
# 7196520  1.108201      7199594          3          0                   NaN
# 7196521  1.108128      7199595          3          0                   NaN
# 7196522  1.108055      7199596          3          0                   NaN
# 7196523  1.107982      7199597          3          0                   NaN
# 7196524  1.107908      7199598          3          0                   NaN
# 7196525  1.107835      7199599          3          0                   NaN
# 7196526  1.107761      7199600          3          0                   NaN
# 7196527  1.107687      7199601          3          0                   NaN
# 7196528  1.107612      7199602          3          0                   NaN
# 7196529  1.107538      7199603          3          0                   NaN
# 7196530  1.107463      7199604          3          0                   NaN
# 7196531  1.107388      7199605          3          0                   NaN
# 7196532  1.107313      7199606          3          0                   NaN
# 7196533  1.107237      7199607          3          0                   NaN
# 7196534  1.107161      7199608          3          0                   NaN
# 7196535  1.107086      7199609          3          0                   NaN
# 7196536  1.107009      7199610          3          0                   NaN
# 7196537  1.106933      7199611          3          0                   NaN
# 7196538  1.106857      7199612          3          0                   NaN
# 7196539  1.106780      7199613          3          0                   NaN
# 7196540  1.106703      7199614          3          0                   NaN
# 7196541  1.106626      7199615          3          0                   NaN
# 7196542  1.106548      7199616          3          0                   NaN
# 7196543  1.106471      7199617          3          0                   NaN
# 7196544  1.106393      7199618          3          0                   NaN
# 7196545  1.106315      7199619          3          0                   NaN
# 7196546  1.106236      7199620          3          0                   NaN
# 7196547  1.106158      7199621          3          0                   NaN
# 7196548  1.106079      7199622          3          0                   NaN
# 7196549  1.106000      7199623          3          0                   NaN
#
#          color
# 0        green
# 1        green
# 2        green
# 3        green
# 4        green
# 5        green
# 6        green
# 7        green
# 8        green
# 9        green
# 10       green
# 11       green
# 12       green
# 13       green
# 14       green
# 15       green
# 16       green
# 17       green
# 18       green
# 19       green
# 20       green
# 21       green
# 22       green
# 23       green
# 24       green
# 25       green
# 26       green
# 27       green
# 28       green
# 29       green
# ...        ...
# 7196520      m
# 7196521      m
# 7196522      m
# 7196523      m
# 7196524      m
# 7196525      m
# 7196526      m
# 7196527      m
# 7196528      m
# 7196529      m
# 7196530      m
# 7196531      m
# 7196532      m
# 7196533      m
# 7196534      m
# 7196535      m
# 7196536      m
# 7196537      m
# 7196538      m
# 7196539      m
# 7196540      m
# 7196541      m
# 7196542      m
# 7196543      m
# 7196544      m
# 7196545      m
# 7196546      m
# 7196547      m
# 7196548      m
# 7196549      m
#
# [14393967 rows x 6 columns]
# 3
# 0
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# /home/franciscosargo/.virtualenvs/pre_epi_seizures/local/lib/python2.7/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# Plotted!

# %%
del y
# Out:
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# <ipython-input-7-9062c79d1164> in <module>()
# ----> 1 del y
#
# NameError: name 'y' is not defined

# %%
client.compute(y)
