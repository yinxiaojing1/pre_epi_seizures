# %%
from time import sleep

def inc(x):
    sleep(1)
    return x + 1

def add(x, y):
    #sleep(1)
    return x + y

def trigger(data):
    print 'sike!!!'

# %%
from dask import delayed

# %%
data = [1, 2, 3, 4, 5, 6, 7, 8]

pll_data = [delayed(inc)(number)
            for number in data]

trigger = delayed(trigger)(pll_data)

trigger.compute()
# Out:
# sike!!!

# %%
# %%time

trigger.compute()
# Out:
# sike!!!
# CPU times: user 8.2 ms, sys: 0 ns, total: 8.2 ms
# Wall time: 1.02 s

# %%
trigger.visualize()
